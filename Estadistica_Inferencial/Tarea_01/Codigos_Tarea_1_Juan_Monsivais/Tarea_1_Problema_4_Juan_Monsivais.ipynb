# %% [markdown]
# ## Ejericio 4 incisos del a) al b)

# %%
set.seed(13)

posiblesResultados <- c("T","H")


experimento <- sample(posiblesResultados, size = 10, replace = TRUE)

print(experimento)

resultados <- matrix(nrow = 10000, ncol = 10)

print("Primeros 3 tres resultados (cantidad de caras): ")

for(i in 1:10000)
{
  experimento <- sample(posiblesResultados, size = 10, replace = TRUE)
  resultados[i, ] <- experimento

  if(i<=3)
  {
    print(resultados[i, ])
  }

}

sumaCaras <- rowSums(resultados[1:3, ] == "H")

print(sumaCaras)


freCaras <- rowSums(resultados == "H")
freCarasF <- table(freCaras)
freCarasP <- prop.table(freCarasF) #Datos de manera proporcional

binomial <- dbinom(0:10,10,0.5)

plot(freCarasF, main = "Frecuencia de caras", xlab = "Numero de caras",
     ylab = "Frecuencia de resultado", col = "#EE6A50")

plot(freCarasP, main = "Proporción de Caras", xlab = "Numero de caras",
     ylab = "Proporción", col = "royalblue", type ="h")

lines(0:10,binomial, type="o", col = "black")

legend("topleft", legend=c("Experimento", "Binomial"),
       fill = c("royalblue", "black"))
# Out:
#  [1] "H" "T" "H" "T" "H" "T" "H" "H" "H" "H"
# [1] "Primeros 3 tres resultados (cantidad de caras): "
#  [1] "H" "T" "H" "H" "T" "T" "H" "H" "T" "T"
#  [1] "T" "T" "H" "T" "H" "H" "H" "H" "T" "T"
#  [1] "T" "H" "T" "T" "H" "H" "T" "H" "T" "T"
# [1] 5 5 4
# Plot with title “Frecuencia de caras”
# Plot with title “Proporción de Caras”

# %% [markdown]
# ## Ejericio 4 inciso c)

# %%
posiblesResultados <- c("T","H")
probabilidadesDeEventos <- c(0.3,0.7)

experimento <- sample(posiblesResultados, size = 10,
                      replace = TRUE, prob = probabilidadesDeEventos)

resultados <- matrix(nrow = 10000, ncol = 10)

print("Primeros tres resultados")

for(i in 1:10000)
{
  experimento <- sample(posiblesResultados, size = 10,
                        replace = TRUE, prob = probabilidadesDeEventos)
  resultados[i, ] <- experimento

  if(i<=3)
  {
    print(resultados[i, ])
  }

}

freCaras <- rowSums(resultados == "H")
freCarasF <- table(freCaras)
freCarasP <- prop.table(freCarasF) #Datos de manera proporcional


binomial <- dbinom(0:10,10,0.7)


plot(freCarasF, main = "Frecuencia de caras", xlab = "Número de caras",
     ylab = "Frecuencia de resultado", col = "#EE6A50")

plot(freCarasP, main = "Proporción de Caras", xlab = "Número de caras",
     ylab = "Proporción", col = "royalblue", type ="h")

lines(0:10,binomial, type="o", col = "black")

legend("topleft", legend=c("Experimento", "Binomial"),
       fill = c("royalblue", "black"))
# Out:
# [1] "Primeros tres resultados"
#  [1] "H" "H" "H" "H" "T" "H" "T" "H" "T" "H"
#  [1] "H" "H" "T" "H" "H" "T" "T" "T" "H" "T"
#  [1] "T" "H" "H" "T" "H" "T" "H" "T" "T" "H"
# Plot with title “Frecuencia de caras”
# Plot with title “Proporción de Caras”
