# %% [markdown]
# # Ejercicio 3 (Teorema Moivre-Laplace)

# %%
# Probabilidad y valor de n
p <- 0.1
q <- 1-p
n <- 5

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.1 y n = 5",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.1 y n = 5”

# %%
# Probabilidad y valor de n
p <- 0.5
q <- 1-p
n <- 5

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.5 y n = 5",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.5 y n = 5”

# %%
# Probabilidad y valor de n
p <- 0.9
q <- 1-p
n <- 5

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.9 y n = 5",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topleft", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.9 y n = 5”

# %%
# Probabilidad y valor de n
p <- 0.1
q <- 1-p
n <- 10

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.1 y n = 10",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.1 y n = 10”

# %%
# Probabilidad y valor de n
p <- 0.5
q <- 1-p
n <- 10

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.5 y n = 10",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.5 y n = 10”

# %%
# Probabilidad y valor de n
p <- 0.9
q <- 1-p
n <- 10

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.9 y n = 10",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topleft", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.9 y n = 10”

# %%
# Probabilidad y valor de n
p <- 0.1
q <- 1-p
n <- 20

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, media + 3*desv, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.1 y n = 20",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.1 y n = 20”

# %%
# Probabilidad y valor de n
p <- 0.5
q <- 1-p
n <- 20

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, n, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("b","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.5 y n = 20",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.5 y n = 20”

# %%
# Probabilidad y valor de n
p <- 0.9
q <- 1-p
n <- 20

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.9 y n = 20",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topleft", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.9 y n = 20”

# %%
# Probabilidad y valor de n
p <- 0.1
q <- 1-p
n <- 100

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(0, media + 3*desv, by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.1 y n = 100",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.1 y n = 100”

# %%
# Probabilidad y valor de n
p <- 0.5
q <- 1-p
n <- 100

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.5 y n = 100",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.5 y n = 100”

# %%
# Probabilidad y valor de n
p <- 0.9
q <- 1-p
n <- 100

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.9 y n = 100",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topleft", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.9 y n = 100”

# %%
# Probabilidad y valor de n
p <- 0.1
q <- 1-p
n <- 500

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.1 y n = 500",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.1 y n = 500”

# %%
# Probabilidad y valor de n
p <- 0.5
q <- 1-p
n <- 500

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("b","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.5 y n = 500",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topright", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.5 y n = 500”

# %%
# Probabilidad y valor de n
p <- 0.9
q <- 1-p
n <- 500

# Cálculo de medias y varianzas
media <- n * p
desv <- sqrt(n * p * q)

# Valores de x para graficar
x <- seq(as.integer(media - 3*desv), as.integer(media + 3*desv), by = 1)

# Calcular las distribuciones
binomial <- dbinom(x, n, p)
normal <- dnorm(x, media, desv)

# Crear una matriz con los valores de ambas distribuciones
matriz_datos <- cbind(binomial, normal)

# Crear el gráfico utilizando matplot
matplot(x, matriz_datos, type = c("p","b"), col = c("blue", "red"), pch = 19, lwd = 2,
        main = "Distribución Binomial vs. Distribución Normal
                p = 0.9 y n = 500",
        xlab = "Valores de x", ylab = "Densidad de Probabilidad")

# Agregar una leyenda
legend("topleft", legend = c("Binomial", "Normal"), col = c("blue", "red"), lwd = 2)
# Out:
# Plot with title “Distribución Binomial vs. Distribución Normal
#                 p = 0.9 y n = 500”
